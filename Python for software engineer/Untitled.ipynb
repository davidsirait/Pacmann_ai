# %%
import requests
import json
from bs4 import BeautifulSoup
import time
import webbrowser
import winsound

# %%
url = "https://atmos.co.id/collections/raffle"
duration = 2000  # milliseconds
freq = 440  # Hz
# set the headers like we are a browser,
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
while True:
    # send the request
    response  = requests.get(url,headers=headers)
    # get the response in text
    text = response.text
    # parse into beautiful soup
    soup = BeautifulSoup(text, 'html')
    
    if 'university' not in str(soup):
        print("Raffle Not Found")
        time.sleep(30)
        continue
    else:
        print("Raffle Found")
        winsound.Beep(freq,duration)
        webbrowser.open(url)
        break
# Out:
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found
# Raffle Not Found

# %%
duration = 2000  # milliseconds
freq = 440  # Hz
